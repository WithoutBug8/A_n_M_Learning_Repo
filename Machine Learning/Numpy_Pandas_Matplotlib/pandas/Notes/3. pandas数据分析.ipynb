# %% [markdown]
# # pandas数据分析
# ### 数据分析流程
# 1. 数据收集
# 2. 数据清洗
#     - 缺失值
#     - 错误数据
#     - 格式混乱
# 3. 数据分析
#     - 统计(平均值，最大值，比例等等)
#     - 分组对比
# 4. 数据可视化
#     - 折线图看趋势
#     - 柱状图对比
#     - 散点图看相关性
# -----

# %% [markdown]
# ### 1. 数据的导入

# %%
import pandas as pd

# %%
df = pd.read_csv()
